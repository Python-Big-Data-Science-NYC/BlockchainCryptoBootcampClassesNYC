# %%
import json
from bs4 import BeautifulSoup
import requests 
 
url = "https://www.cryptocompare.com/api/data/coinlist/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
data = json.loads(soup.prettify())
data = data['Data']
 
print(data)  # display the content
# Out:
# {'BBK': {'Sponsored': False, 'ImageUrl': '/media/30002250/bbk.jpg', 'Symbol': 'BBK', 'Algorithm': 'Scrypt', 'SortOrder': '2640', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'BBK', 'TotalCoinSupply': '500000000', 'CoinName': 'BitBlocks', 'ProofType': 'PoW/PoS', 'FullName': 'BitBlocks (BBK)', 'Id': '863235', 'Url': '/coins/bbk/overview'}, 'LCT': {'Sponsored': False, 'ImageUrl': '/media/25792592/lct.png', 'Symbol': 'LCT', 'Algorithm': 'N/A', 'SortOrder': '2103', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'LCT', 'TotalCoinSupply': '6500000', 'CoinName': 'LendConnect', 'ProofType': 'N/A', 'FullName': 'LendConnect (LCT)', 'Id': '688295', 'Url': '/coins/lct/overview'}, 'PXI': {'Sponsored': False, 'ImageUrl': '/media/350559/pxi.png', 'Symbol': 'PXI', 'Algorithm': 'X11', 'SortOrder': '478', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'PXI', 'TotalCoinSupply': 'N/A', 'CoinName': 'Prime-X1', 'ProofType': 'PoW', 'FullName': 'Prime-X1 (PXI)', 'Id': '15274', 'Url': '/coins/pxi/overview'}, 'IETH': {'Sponsored': False, 'ImageUrl': '/media/20780777/ieth.png', 'Symbol': 'IETH', 'Algorithm': 'N/A', 'SortOrder': '2070', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'IETH', 'TotalCoinSupply': '18000000', 'CoinName': 'iEthereum', 'ProofType': 'N/A', 'FullName': 'iEthereum (IETH)', 'Id': '667344', 'Url': '/coins/ieth/overview'}, 'XG': {'Sponsored': False, 'ImageUrl': '/media/20156/xg.png', 'Symbol': 'XG', 'Algorithm': 'XG Hash', 'SortOrder': '344', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'XG', 'TotalCoinSupply': '0', 'CoinName': 'XG Sports', 'ProofType': 'PoW/PoS', 'FullName': 'XG Sports (XG)', 'Id': '5376', 'Url': '/coins/xg/overview'}, 'DIGS': {'Sponsored': False, 'ImageUrl': '/media/20706/digs.png', 'Symbol': 'DIGS', 'Algorithm': 'Scrypt', 'SortOrder': '464', 'PreMinedValue': 'N/A', 'FullyPremined': '1', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'DIGS', 'TotalCoinSupply': '100000000', 'CoinName': 'Diggits', 'ProofType': 'PoS', 'FullName': 'Diggits (DIGS)', 'Id': '12192', 'Url': '/coins/digs/overview'}, 'DTT*': {'Sponsored': False, 'ImageUrl': '/media/14761941/dtt1.png', 'Symbol': 'DTT*', 'Algorithm': 'N/A', 'SortOrder': '1769', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'DTT*', 'TotalCoinSupply': 'N/A', 'CoinName': 'Data Trading', 'ProofType': 'N/A', 'FullName': 'Data Trading (DTT*)', 'Id': '363066', 'Url': '/coins/dttstar/overview'}, 'CLR': {'Sponsored': False, 'ImageUrl': '/media/19657/clr.png', 'Symbol': 'CLR', 'Algorithm': 'SHA256', 'SortOrder': '87', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'CLR', 'TotalCoinSupply': '27200000', 'CoinName': 'CopperLark', 'ProofType': 'PoW', 'FullName': 'CopperLark (CLR)', 'Id': '4418', 'Url': '/coins/clr/overview'}, 'RED': {'Sponsored': False, 'ImageUrl': '/media/1383265/red.png', 'Symbol': 'RED', 'Algorithm': 'Scrypt', 'SortOrder': '1221', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'RED', 'TotalCoinSupply': 'N/A', 'CoinName': 'Redcoin', 'ProofType': 'PoW', 'FullName': 'Redcoin (RED)', 'Id': '79864', 'Url': '/coins/red/overview'}, 'EGG': {'Sponsored': False, 'ImageUrl': '/media/20269/egg.png', 'Symbol': 'EGG', 'Algorithm': 'Scrypt', 'SortOrder': '363', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'EGG', 'TotalCoinSupply': '3891', 'CoinName': 'EggCoin', 'ProofType': 'PoW/PoS', 'FullName': 'EggCoin (EGG)', 'Id': '5395', 'Url': '/coins/egg/overview'}, 'MAT*': {'Sponsored': False, 'ImageUrl': '/media/1383371/mat.png', 'Symbol': 'MAT*', 'Algorithm': 'Scrypt', 'SortOrder': '1239', 'PreMinedValue': 'N/A', 'FullyPremined': '0', 'TotalCoinsFreeFloat': 'N/A', 'Name': 'MAT*', 'TotalCoinSupply': '215000000', 'CoinName': 'Manet Coin', 'ProofType': 'PoW/PoS', 'FullNa ...

# %%
crypto_lst = sorted(list(data.keys()))
print(crypto_lst)
# Out:
# ['007', '1337', '1CR', '1ST', '2015', '2BACCO', '2GIVE', '300', '32BIT', '365', '3DES', '404', '42', '611', '808', '888', '8BIT', '8BT', '8S', 'ABC', 'ABJ', 'ABT', 'ABT*', 'ABY', 'ABYSS', 'AC', 'AC3', 'ACAT', 'ACC', 'ACC*', 'ACCO', 'ACE', 'ACES', 'ACH', 'ACID', 'ACN', 'ACOIN', 'ACP', 'ACT', 'ACT*', 'ACTN', 'ADA', 'ADB', 'ADC', 'ADCN', 'ADH', 'ADK', 'ADL', 'ADM', 'ADN', 'ADST', 'ADT', 'ADX', 'ADZ', 'AE', 'AEC', 'AEON', 'AERM', 'AERO', 'AET', 'AGI', 'AGRS', 'AGS', 'AHT', 'AHT*', 'AIB', 'AIC', 'AID', 'AIDOC', 'AION', 'AIR', 'AIR*', 'AIT', 'AITT', 'AIX', 'AKA', 'ALC', 'ALEX', 'ALF', 'ALIS', 'ALN', 'ALPS', 'ALQO', 'ALT', 'ALTCOM', 'ALTOCAR', 'ALX', 'AM', 'AMB', 'AMBER', 'AMBT', 'AMC', 'AMIS', 'AMM', 'AMMO', 'AMN', 'AMO', 'AMP', 'AMS', 'AMT', 'AMY', 'ANAL', 'ANC', 'ANCP', 'AND', 'ANI', 'ANK', 'ANT', 'ANTC', 'ANTI', 'ANTS', 'APC', 'APEX', 'APH', 'APPC', 'APT', 'APX', 'AR*', 'ARB', 'ARBI', 'ARC', 'ARC*', 'ARCH', 'ARCO', 'ARCT', 'ARDR', 'ARENA', 'ARG', 'ARGUS', 'ARI', 'ARI*', 'ARK', 'ARM', 'ARN', 'ARNA*', 'ARPA', 'ART', 'ARTE', 'ARY', 'ASAFE2', 'ASN', 'AST', 'AST*', 'ASTRO', 'ATB', 'ATCC', 'ATFS', 'ATKN', 'ATL', 'ATM', 'ATM*', 'ATMOS', 'ATOM', 'ATOM*', 'ATS', 'ATX', 'AUA', 'AUC', 'AUN', 'AUR', 'AURA', 'AURS', 'AUT', 'AUTO', 'AV', 'AVA', 'AVE', 'AVL', 'AVT', 'AXIOM', 'AXP', 'AXR', 'AXS', 'AXT', 'AXYS', 'B2B', 'B3', 'B@', 'BAC', 'BAC*', 'BAN', 'BANCA', 'BAR', 'BAS', 'BASH', 'BASHC', 'BAT', 'BAX', 'BAY', 'BBC', 'BBCC', 'BBI', 'BBK', 'BBN', 'BBN*', 'BBP', 'BBR', 'BBT', 'BBT*', 'BCA', 'BCAP', 'BCCOIN', 'BCD', 'BCD*', 'BCDN', 'BCF', 'BCH', 'BCI', 'BCIO', 'BCN', 'BCO*', 'BCOIN', 'BCPT', 'BCR', 'BCR*', 'BCT', 'BCX', 'BCX*', 'BCY', 'BDG', 'BDL', 'BDP', 'BDR', 'BEE', 'BELA', 'BEN', 'BENJI', 'BERN', 'BERRY', 'BEST', 'BET', 'BET*', 'BETR', 'BETT', 'BEX', 'BEZ', 'BFDT', 'BFT', 'BFX', 'BHC', 'BHC*', 'BIC', 'BIFI', 'BIGUP', 'BINS', 'BIO', 'BIOB', 'BIOS', 'BIP', 'BIS', 'BIT', 'BIT16', 'BITB', 'BITCAR', 'BITCNY', 'BITG', 'BITGOLD', 'BITOK', 'BITS', 'BITSD', 'BITSILVER', 'BITUSD', 'BITZ', 'BIX', 'BKC', 'BKX', 'BLAS', 'BLAZR', 'BLC', 'BLITZ', 'BLK', 'BLN*', 'BLOCK', 'BLOCKPAY', 'BLRY', 'BLT', 'BLU', 'BLUE', 'BLX', 'BLZ', 'BM', 'BM*', 'BMC', 'BMH', 'BMK', 'BMT', 'BMX', 'BMXT', 'BNB', 'BNB*', 'BNC', 'BNK', 'BNT', 'BNTN', 'BNTY', 'BNX', 'BOAT', 'BOB*', 'BOG', 'BOLD', 'BOLI', 'BOMB', 'BON', 'BON*', 'BOOM', 'BOS', 'BOSON', 'BOSS', 'BOST', 'BOT', 'BOTC', 'BOTS', 'BOU', 'BOXY', 'BPL', 'BPT', 'BQ', 'BQC', 'BQX', 'BRAIN', 'BRAT', 'BRC', 'BRC*', 'BRD', 'BRDD', 'BRIA', 'BRIT', 'BRK', 'BRO', 'BRONZ', 'BRX', 'BS', 'BSC', 'BSD*', 'BSR', 'BST', 'BSTAR', 'BSTK', 'BSTY', 'BSX', 'BT', 'BT1', 'BT2', 'BTA', 'BTB', 'BTC', 'BTCA', 'BTCD', 'BTCE', 'BTCE*', 'BTCGO', 'BTCH', 'BTCI', 'BTCL', 'BTCL*', 'BTCM', 'BTCP', 'BTCR', 'BTCRED', 'BTCRY', 'BTCS', 'BTCZ', 'BTD', 'BTDX', 'BTE', 'BTF', 'BTG', 'BTG*', 'BTH', 'BTL', 'BTLC', 'BTM', 'BTM*', 'BTMI', 'BTO', 'BTPL', 'BTQ', 'BTRM', 'BTS', 'BTSE', 'BTT', 'BTTF', 'BTW', 'BTX', 'BTX*', 'BTZ', 'BUBO', 'BUCKS', 'BUCKS*', 'BUK', 'BULLS', 'BUN', 'BURST', 'BUZZ', 'BVC', 'BWK', 'BXC', 'BXT', 'BYC', 'BZNT', 'BamitCoin', 'C2', 'C20', 'CAB', 'CABS', 'CABS*', 'CACH', 'CAG', 'CAIX', 'CALC', 'CAM', 'CAN', 'CANN', 'CAP', 'CAPP', 'CARBON', 'CARE', 'CARE*', 'CAS', 'CASH', 'CASH*', 'CAT', 'CAT*', 'CAT1', 'CAV', 'CBC', 'CBC*', 'CBD', 'CBS', 'CBT', 'CBX', 'CC', 'CCC', 'CCN', 'CCOS', 'CCRB', 'CCT', 'CCX', 'CDN', 'CDT', 'CDX', 'CDX*', 'CDY', 'CEDEX', 'CEEK', 'CEFS', 'CEL', 'CELL', 'CESC', 'CETI', 'CF', 'CFC', 'CFD', 'CFI', 'CFT', 'CFT*', 'CFTY', 'CGA', 'CHA', 'CHAN', 'CHAO', 'CHARM', 'CHASH', 'CHAT', 'CHBR', 'CHC', 'CHESS', 'CHF*', 'CHFN', 'CHI', 'CHIEF', 'CHILD', 'CHIP', 'CHIPS*', 'CHOOF', 'CHP', 'CHSB', 'CHT', 'CIF', 'CIN', 'CINNI', 'CIR', 'CIRC', 'CIX', 'CJ', 'CJC', 'CJT', 'CKC', 'CL', 'CLAM', 'CLD', 'CLICK', 'CLIN', 'CLINT', 'CLN', 'CLO*', 'CLOAK', 'CLOUT', 'CLR', 'CLR*', 'CLUB', 'CLUD', 'CLV', 'CMC', 'CMCT', 'CMM', 'CMOS', 'CMP', 'CMPCO', 'CMS', 'CMT', 'CMT*', 'CNBC', 'CNC', 'CND', 'CND*', 'CNL', 'CNMT', 'CNN', 'CNO', 'CNT', 'CNX', 'CO2', 'COAL', 'COB',  ...

# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
 
url = "https://api.coinmarketcap.com/v1/ticker/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
dic = json.loads(soup.prettify())
 
# create an empty DataFrame
df = pd.DataFrame(columns=["Ticker", "MarketCap"])
 
for i in range(len(dic)):
    df.loc[len(df)] = [dic[i]['symbol'], dic[i]['market_cap_usd']]
 
df.sort_values(by=['MarketCap'])
# apply conversion to numeric as 'df' contains lots of 'None' string as values
df.MarketCap = pd.to_numeric(df.MarketCap)

# %%
df
# Out:
#    Ticker     MarketCap
# 0     BTC  1.104815e+11
# 1     ETH  4.937234e+10
# 2     XRP  2.073683e+10
# 3     BCH  1.457749e+10
# 4     EOS  9.416022e+09
# 5     LTC  5.447886e+09
# 6     XLM  4.277896e+09
# 7     ADA  4.186107e+09
# 8   MIOTA  3.283042e+09
# 9     TRX  2.792211e+09
# 10   USDT  2.620098e+09
# 11    NEO  2.431845e+09
# 12   DASH  2.107767e+09
# 13    XMR  2.034563e+09
# 14    BNB  1.777790e+09
# 15    XEM  1.742571e+09
# 16    VEN  1.576650e+09
# 17    ETC  1.461873e+09
# 18   QTUM  9.444810e+08
# 19    OMG  9.278811e+08
# 20    ONT  9.086502e+08
# 21    ZEC  7.879855e+08
# 22    ICX  7.648361e+08
# 23    BCN  7.594567e+08
# 24    LSK  6.958164e+08
# 25    ZIL  6.482298e+08
# 26    DCR  6.383614e+08
# 27     AE  6.043922e+08
# 28    BTM  5.745123e+08
# 29    BTG  5.600170e+08
# ..    ...           ...
# 70    CMT  1.487030e+08
# 71    RDD  1.465203e+08
# 72   MAID  1.464075e+08
# 73   WICC  1.420493e+08
# 74   VERI  1.375526e+08
# 75    DCN  1.355964e+08
# 76    FSN  1.324363e+08
# 77    GAS  1.308687e+08
# 78    KNC  1.307786e+08
# 79  ETHOS  1.289987e+08
# 80   MITH  1.275511e+08
# 81   LOOM  1.273047e+08
# 82    BIX  1.260217e+08
# 83    SYS  1.201472e+08
# 84    FUN  1.200603e+08
# 85   CTXC  1.176915e+08
# 86    KIN  1.145284e+08
# 87    NXT  1.138370e+08
# 88    EMC  1.104065e+08
# 89   DROP  1.101375e+08
# 90   QASH  1.085931e+08
# 91   POLY  1.082992e+08
# 92    DDD  1.043619e+08
# 93    ENG  1.043560e+08
# 94  THETA  1.026100e+08
# 95   MANA  1.021647e+08
# 96    SUB  1.015680e+08
# 97   NULS  1.008112e+08
# 98  BLOCK  9.982406e+07
# 99    SOC  9.935910e+07
#
# [100 rows x 2 columns]

# %%
P = df[df.MarketCap > 20e6]
print(P, end="\n\n")
 
portfolio = list(P.Ticker)
print(portfolio)
# Out:
#    Ticker     MarketCap
# 0     BTC  1.104815e+11
# 1     ETH  4.937234e+10
# 2     XRP  2.073683e+10
# 3     BCH  1.457749e+10
# 4     EOS  9.416022e+09
# 5     LTC  5.447886e+09
# 6     XLM  4.277896e+09
# 7     ADA  4.186107e+09
# 8   MIOTA  3.283042e+09
# 9     TRX  2.792211e+09
# 10   USDT  2.620098e+09
# 11    NEO  2.431845e+09
# 12   DASH  2.107767e+09
# 13    XMR  2.034563e+09
# 14    BNB  1.777790e+09
# 15    XEM  1.742571e+09
# 16    VEN  1.576650e+09
# 17    ETC  1.461873e+09
# 18   QTUM  9.444810e+08
# 19    OMG  9.278811e+08
# 20    ONT  9.086502e+08
# 21    ZEC  7.879855e+08
# 22    ICX  7.648361e+08
# 23    BCN  7.594567e+08
# 24    LSK  6.958164e+08
# 25    ZIL  6.482298e+08
# 26    DCR  6.383614e+08
# 27     AE  6.043922e+08
# 28    BTM  5.745123e+08
# 29    BTG  5.600170e+08
# ..    ...           ...
# 70    CMT  1.487030e+08
# 71    RDD  1.465203e+08
# 72   MAID  1.464075e+08
# 73   WICC  1.420493e+08
# 74   VERI  1.375526e+08
# 75    DCN  1.355964e+08
# 76    FSN  1.324363e+08
# 77    GAS  1.308687e+08
# 78    KNC  1.307786e+08
# 79  ETHOS  1.289987e+08
# 80   MITH  1.275511e+08
# 81   LOOM  1.273047e+08
# 82    BIX  1.260217e+08
# 83    SYS  1.201472e+08
# 84    FUN  1.200603e+08
# 85   CTXC  1.176915e+08
# 86    KIN  1.145284e+08
# 87    NXT  1.138370e+08
# 88    EMC  1.104065e+08
# 89   DROP  1.101375e+08
# 90   QASH  1.085931e+08
# 91   POLY  1.082992e+08
# 92    DDD  1.043619e+08
# 93    ENG  1.043560e+08
# 94  THETA  1.026100e+08
# 95   MANA  1.021647e+08
# 96    SUB  1.015680e+08
# 97   NULS  1.008112e+08
# 98  BLOCK  9.982406e+07
# 99    SOC  9.935910e+07
#
# [100 rows x 2 columns]
#
# ['BTC', 'ETH', 'XRP', 'BCH', 'EOS', 'LTC', 'XLM', 'ADA', 'MIOTA', 'TRX', 'USDT', 'NEO', 'DASH', 'XMR', 'BNB', 'XEM', 'VEN', 'ETC', 'QTUM', 'OMG', 'ONT', 'ZEC', 'ICX', 'BCN', 'LSK', 'ZIL', 'DCR', 'AE', 'BTM', 'BTG', 'ZRX', 'SC', 'STEEM', 'XVG', 'BTS', 'RHOC', 'BCD', 'REP', 'MKR', 'NANO', 'WAVES', 'DOGE', 'GNT', 'PPT', 'STRAT', 'BTCP', 'WAN', 'DGB', 'SNT', 'WTC', 'NAS', 'BAT', 'HSR', 'AION', 'IOST', 'DGD', 'KCS', 'HT', 'LRC', 'KMD', 'GXS', 'ARDR', 'ELF', 'CNX', 'BNT', 'ARK', 'MONA', 'ELA', 'MOAC', 'PIVX', 'CMT', 'RDD', 'MAID', 'WICC', 'VERI', 'DCN', 'FSN', 'GAS', 'KNC', 'ETHOS', 'MITH', 'LOOM', 'BIX', 'SYS', 'FUN', 'CTXC', 'KIN', 'NXT', 'EMC', 'DROP', 'QASH', 'POLY', 'DDD', 'ENG', 'THETA', 'MANA', 'SUB', 'NULS', 'BLOCK', 'SOC']

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
import json
from bs4 import BeautifulSoup
import requests
 
 
def timestamp2date(timestamp):
    # function converts a Unix timestamp into Gregorian date
    return datetime.fromtimestamp(int(timestamp)).strftime('%Y-%m-%d')
 
def date2timestamp(date):
    # function coverts Gregorian date in a given format to timestamp
    return datetime.strptime(date_today, '%Y-%m-%d').timestamp()
 
 
def fetchCryptoOHLC(fsym, tsym):
    # function fetches a crypto price-series for fsym/tsym and stores
    # it in pandas DataFrame
 
    cols = ['date', 'timestamp', 'open', 'high', 'low', 'close']
    lst = ['time', 'open', 'high', 'low', 'close']
 
    timestamp_today = datetime.today().timestamp()
    curr_timestamp = timestamp_today
 
    for j in range(2):
        df = pd.DataFrame(columns=cols)
        url = "https://min-api.cryptocompare.com/data/histoday?fsym=" + fsym + "&tsym=" + tsym + "&toTs=" + str(int(curr_timestamp)) + "&limit=2000"
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        dic = json.loads(soup.prettify())
        for i in range(1, 2001):
            tmp = []
            for e in enumerate(lst):
                x = e[0]
                y = dic['Data'][i][e[1]]
                if(x == 0):
                    tmp.append(str(timestamp2date(y)))
                tmp.append(y)
            if(np.sum(tmp[-4::]) > 0):
                df.loc[len(df)] = np.array(tmp)
        df.index = pd.to_datetime(df.date)
        df.drop('date', axis=1, inplace=True)
        curr_timestamp = int(df.ix[0][0])
        if(j == 0):
            df0 = df.copy()
        else:
            data = pd.concat([df, df0], axis=0)
 
    return data
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
fsym = "BTC"
tsym = "USD"
data = fetchCryptoOHLC(fsym, tsym)
 
# print the BTC/USD OHLC price-series
print(data)
 
# plot them all
plt.figure(figsize=(10,4))
plt.plot(data.open)
plt.plot(data.high)
plt.plot(data.low)
plt.plot(data.close)
plt.legend(loc=2)
plt.title(fsym, fontsize=12)
plt.ylabel(tsym, fontsize=12)
# Out:
#              timestamp     open     high      low    close
# date
# 2010-07-17  1279324800  0.04951  0.04951  0.04951  0.04951
# 2010-07-18  1279411200  0.04951  0.08585  0.05941  0.08584
# 2010-07-19  1279497600  0.08584  0.09307  0.07723   0.0808
# 2010-07-20  1279584000   0.0808  0.08181  0.07426  0.07474
# 2010-07-21  1279670400  0.07474  0.07921  0.06634  0.07921
# 2010-07-22  1279756800  0.07921  0.08181   0.0505   0.0505
# 2010-07-23  1279843200   0.0505  0.06767   0.0505  0.06262
# 2010-07-24  1279929600  0.06262  0.06161  0.05049  0.05454
# 2010-07-25  1280016000  0.05454  0.05941   0.0505   0.0505
# 2010-07-26  1280102400   0.0505    0.056     0.05    0.056
# 2010-07-27  1280188800    0.056   0.0605    0.053     0.06
# 2010-07-28  1280275200     0.06    0.062    0.054   0.0589
# 2010-07-29  1280361600   0.0589   0.0699   0.0571   0.0699
# 2010-07-30  1280448000   0.0699   0.0698   0.0582   0.0627
# 2010-07-31  1280534400   0.0627  0.06889    0.056  0.06785
# 2010-08-01  1280620800  0.06785    0.065     0.06   0.0611
# 2010-08-02  1280707200   0.0611   0.0633     0.06     0.06
# 2010-08-03  1280793600     0.06    0.065    0.059     0.06
# 2010-08-04  1280880000     0.06  0.06231    0.057    0.057
# 2010-08-05  1280966400    0.057    0.061    0.058    0.061
# 2010-08-06  1281052800    0.061   0.0624   0.0607   0.0623
# 2010-08-07  1281139200   0.0623   0.0622    0.059    0.059
# 2010-08-08  1281225600    0.059    0.061    0.059   0.0609
# 2010-08-09  1281312000   0.0609   0.0735   0.0593    0.071
# 2010-08-10  1281398400    0.071   0.0709  0.06651     0.07
# 2010-08-11  1281484800     0.07  0.07541     0.06    0.067
# 2010-08-12  1281571200    0.067     0.07  0.06141     0.07
# 2010-08-13  1281657600     0.07    0.068   0.0645   0.0645
# 2010-08-14  1281744000   0.0645   0.0695   0.0645    0.067
# 2010-08-15  1281830400    0.067    0.067    0.065  0.06529
# ...                ...      ...      ...      ...      ...
# 2018-05-18  1526601600  8071.04  8280.45  7940.35  8247.91
# 2018-05-19  1526688000  8247.91  8397.27   8160.8  8249.24
# 2018-05-20  1526774400  8249.24  8591.45  8181.46     8533
# 2018-05-21  1526860800  8533.22  8585.85  8347.88  8419.65
# 2018-05-22  1526947200  8419.67   8428.6  7962.43  7992.75
# 2018-05-23  1527033600  7992.75  8031.63  7460.66  7505.77
# 2018-05-24  1527120000  7505.77  7729.48  7283.77  7584.74
# 2018-05-25  1527206400  7584.78  7652.37  7347.96  7475.36
# 2018-05-26  1527292800  7475.36  7626.69  7314.71  7355.06
# 2018-05-27  1527379200  7355.06  7420.07  7256.67  7362.23
# 2018-05-28  1527465600  7362.23  7455.55  7092.91  7118.88
# 2018-05-29  1527552000  7118.88  7533.03  7069.01  7474.75
# 2018-05-30  1527638400  7474.75  7571.08  7295.78  7393.02
# 2018-05-31  1527724800  7393.02  7608.87  7349.52  7502.15
# 2018-06-01  1527811200  7501.74  7614.66  7370.27  7530.55
# 2018-06-02  1527897600  7530.55  7697.34  7467.79  7643.26
# 2018-06-03  1527984000  7643.26  7774.96  7606.76  7719.75
# 2018-06-04  1528070400  7719.73  7760.73  7469.21   7503.2
# 2018-06-05  1528156800  7503.32   7672.7  7394.97   7629.4
# 2018-06-06  1528243200   7629.4  7701.35  7504.98  7661.79
# 2018-06-07  1528329600  7661.79  7755.92  7651.13  7700.11
# 2018-06-08  1528416000   7700.4  7709.61   7559.5  7627.52
# 2018-06-09  1528502400  7627.56  7691.74  7495.72  7513.69
# 2018-06-10  1528588800  7513.76  7514.04  6661.98  6773.72
# 2018-06-11  1528675200  6773.72  6913.85  6652.89  6887.37
# 2018-06-12  1528761600  6887.43  6888.33  6462.61  6556.94
# 2018-06-13  1528848000  6556.94     6623  6140.63  6310.43
# 2018-06-14  1528934400  6310.43  6719.44  6286.23  6643.26
# 2018-06-15  1529020800  6643.63  6667.23  6380.69  6396.71
# 2018-06-16  1529107200  6396.71  6510.57  6391.43  6409.07
#
# [2893 rows x 5 columns]
# Text(0,0.5,'USD')

# %%
# Cryptocurrencies using PCA
#
# (c) 2017 QuantAtRisk.com, by Pawel Lachowicz
 
 
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator
from datetime import datetime
import json
from bs4 import BeautifulSoup
import requests
 
# define some custom colours
grey = .6, .6, .6
 
 
def timestamp2date(timestamp):
    # function converts a Unix timestamp into Gregorian date
    return datetime.fromtimestamp(int(timestamp)).strftime('%Y-%m-%d')
 
def date2timestamp(date):
    # function coverts Gregorian date in a given format to timestamp
    return datetime.strptime(date_today, '%Y-%m-%d').timestamp()
 
def fetchCryptoClose(fsym, tsym):
    # function fetches the close-price time-series from cryptocompare.com
    # it may ignore USDT coin (due to near-zero pricing)
    # daily sampled
    cols = ['date', 'timestamp', fsym]
    lst = ['time', 'open', 'high', 'low', 'close']
    timestamp_today = datetime.today().timestamp()
    curr_timestamp = timestamp_today
 
    for j in range(2):
        df = pd.DataFrame(columns=cols)
        url = "https://min-api.cryptocompare.com/data/histoday?fsym=" + fsym + \
              "&tsym=" + tsym + "&toTs=" + str(int(curr_timestamp)) + "&limit=2000"
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        dic = json.loads(soup.prettify())
        for i in range(1, 2001):
            tmp = []
            for e in enumerate(lst):
                x = e[0]
                y = dic['Data'][i][e[1]]
                if(x == 0):
                    tmp.append(str(timestamp2date(y)))
                tmp.append(y)
            if(np.sum(tmp[-4::]) > 0):  # remove for USDT
                tmp = np.array(tmp)
                tmp = tmp[[0,1,4]]  # filter solely for close prices
                df.loc[len(df)] = np.array(tmp)
        # ensure a correct date format
        df.index = pd.to_datetime(df.date, format="%Y-%m-%d")
        df.drop('date', axis=1, inplace=True)
        curr_timestamp = int(df.ix[0][0])
        if(j == 0):
            df0 = df.copy()
        else:
            data = pd.concat([df, df0], axis=0)
    data.drop("timestamp", axis=1, inplace=True)
 
    return data  # DataFrame

# %%
fsym = ['BTC', 'ETH', 'DASH', 'XMR', 'XRP', 'LTC', 'ETC', 'XEM', 'REP', 
        'MAID', 'ZEC', 'STEEM', 'GNT', 'FCT', 'ICN', 'DGD', 
        'WAVES', 'DCR', 'LSK', 'DOGE', 'PIVX']


# vs. 
tsym = 'USD'

# %%
fsym2 = ['BTC',
'ETH',
'XRP',
'BCH',
'EOS',
'LTC',
'XLM',
'ADA',
'MIOTA',
'TRX',
'USDT',
'NEO',
'DASH',
'XMR',
'BNB',
'XEM',
'VEN',
'ETC',
'QTUM',
'OMG',
'ONT',
'ZEC',
'ICX',
'BCN',
'LSK',
'ZIL',
'DCR',
'AE',
'BTM',
'BTG',
'ZRX',
'SC',
'STEEM',
'BTS',
'XVG',
'RHOC',
'BCD',
'REP',
'NANO',
'MKR',
'WAVES',
'DOGE',
'GNT',
'PPT',
'STRAT',
'BTCP',
'WAN',
'DGB',
'WTC',
'SNT',
'BAT',
'NAS']

# %%
for e in enumerate(fsym2):
    print(e[0], e[1])
    if(e[0] == 0):
        try:
            data = fetchCryptoClose(e[1], tsym)
        except:
            pass
    else:
        try:
            data = data.join(fetchCryptoClose(e[1], tsym))
        except:
            pass
 
data = data.astype(float)  # ensure values to be floats
 
# save portfolio to a file (HDF5 file format)
store = pd.HDFStore('portfolio.h5')
store['data'] = data
store.close()
 
# read in your portfolio from a file
df = pd.read_hdf('portfolio.h5', 'data')
print(df)

# %%
df = pd.read_hdf('portfolio.h5', 'data')
df.to_csv('portfolio.csv')
