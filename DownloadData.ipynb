# %%
import json
from bs4 import BeautifulSoup
import requests 
 
url = "https://www.cryptocompare.com/api/data/coinlist/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
data = json.loads(soup.prettify())
data = data['Data']
 
print(data)  # display the content
# Out:
# {'BHC': {'Name': 'BHC', 'SortOrder': '815', 'Id': '29559', 'Url': '/coins/bhc/overview', 'CoinName': 'BighanCoin', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'PoW', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'Quark', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '411000000', 'FullyPremined': '0', 'ImageUrl': '/media/351660/bhc.png', 'Symbol': 'BHC', 'BuiltOn': 'N/A', 'FullName': 'BighanCoin (BHC)'}, 'NPXS': {'Name': 'NPXS', 'SortOrder': '2178', 'Id': '731516', 'Url': '/coins/npxs/overview', 'CoinName': 'Pundi X', 'Sponsored': False, 'SmartContractAddress': '0xa15c7ebe1f07caf6bff097d8a589fb8ac49ae5b3', 'ProofType': 'N/A', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'N/A', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '45828700875.992774', 'FullyPremined': '0', 'ImageUrl': '/media/27010505/pxs.png', 'Symbol': 'NPXS', 'BuiltOn': '7605', 'FullName': 'Pundi X (NPXS)'}, 'CSTL': {'Name': 'CSTL', 'SortOrder': '1872', 'Id': '400432', 'Url': '/coins/cstl/overview', 'CoinName': 'Castle', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'PoW/PoS', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'X11', 'PreMinedValue': 'N/A', 'TotalCoinSupply': ' 200000000', 'FullyPremined': '0', 'ImageUrl': '/media/15887421/cstl.png', 'Symbol': 'CSTL', 'BuiltOn': 'N/A', 'FullName': 'Castle (CSTL)'}, 'GBIT': {'Name': 'GBIT', 'SortOrder': '1047', 'Id': '42103', 'Url': '/coins/gbit/overview', 'CoinName': 'GravityBit', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'PoW/PoS', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'Scrypt', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '5333000', 'FullyPremined': '0', 'ImageUrl': '/media/1382382/gbit.jpg', 'Symbol': 'GBIT', 'BuiltOn': 'N/A', 'FullName': 'GravityBit (GBIT)'}, 'FIRE': {'Name': 'FIRE', 'SortOrder': '797', 'Id': '29196', 'Url': '/coins/fire/overview', 'CoinName': 'FireCoin', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'PoW/PoS', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'X15', 'PreMinedValue': 'N/A', 'TotalCoinSupply': 'N/A', 'FullyPremined': '0', 'ImageUrl': '/media/351625/fire.png', 'Symbol': 'FIRE', 'BuiltOn': 'N/A', 'FullName': 'FireCoin (FIRE)'}, 'AURS': {'Name': 'AURS', 'SortOrder': '1711', 'Id': '341400', 'Url': '/coins/aurs/overview', 'CoinName': 'Aureus', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'N/A', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'Scrypt', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '21000000', 'FullyPremined': '1', 'ImageUrl': '/media/12318345/aurs.png', 'Symbol': 'AURS', 'BuiltOn': 'N/A', 'FullName': 'Aureus (AURS)'}, 'ABC': {'Name': 'ABC', 'SortOrder': '1577', 'Id': '303943', 'Url': '/coins/abc/overview', 'CoinName': 'AB-Chain', 'Sponsored': False, 'SmartContractAddress': '0xec491c1088eae992b7a214efb0a266ad0927a72a', 'ProofType': 'N/A', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'N/A', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '210000000', 'FullyPremined': '0', 'ImageUrl': '/media/12318006/bac.png', 'Symbol': 'ABC', 'BuiltOn': '7605', 'FullName': 'AB-Chain (ABC)'}, 'WMC': {'Name': 'WMC', 'SortOrder': '631', 'Id': '21871', 'Url': '/coins/wmc/overview', 'CoinName': 'WMCoin', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'PoS', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'X11', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '1000000000', 'FullyPremined': '0', 'ImageUrl': '/media/351044/wmc.png', 'Symbol': 'WMC', 'BuiltOn': 'N/A', 'FullName': 'WMCoin (WMC)'}, 'OPP': {'Name': 'OPP', 'SortOrder': '1639', 'Id': '323787', 'Url': '/coins/opp/overview', 'CoinName': 'Opporty', 'Sponsored': False, 'SmartContractAddress': 'N/A', 'ProofType': 'N/A', 'TotalCoinsFreeFloat': 'N/A', 'Algorithm': 'N/A', 'PreMinedValue': 'N/A', 'TotalCoinSupply': '1000000000', 'FullyPremined': '0', 'ImageUrl': '/media/12318188/opp.png', 'Symbol': 'OPP', 'BuiltOn': '7605', 'FullName': 'Opporty (OPP)'}, 'MDA': {'Name': 'MDA', 'SortOrder': '1709', 'Id': '341279', 'Url': '/coins/mda/overview', 'CoinName': 'Moeda', 'Sponsored': Fa ...

# %%
crypto_lst = sorted(list(data.keys()))
print(crypto_lst)
# Out:
# ['007', '0XBTC', '0xDIARY', '1337', '1CR', '1ST', '2015', '2BACCO', '2GIVE', '300', '32BIT', '365', '3DES', '404', '42', '611', '808', '888', '8BIT', '8BT', 'ABC', 'ABJ', 'ABS', 'ABT', 'ABT*', 'ABY', 'ABYSS', 'AC', 'AC3', 'ACAT', 'ACC', 'ACC*', 'ACCO', 'ACE', 'ACES', 'ACH', 'ACID', 'ACN', 'ACOIN', 'ACP', 'ACT', 'ACT*', 'ACTN', 'ADA', 'ADB', 'ADC', 'ADCN', 'ADH', 'ADK', 'ADL', 'ADM', 'ADN', 'ADST', 'ADT', 'ADX', 'ADZ', 'AE', 'AEC', 'AEC*', 'AEN', 'AEON', 'AERM', 'AERO', 'AET', 'AGI', 'AGRS', 'AGS', 'AHT', 'AHT*', 'AIB', 'AIC', 'AID', 'AIDOC', 'AIMS', 'AION', 'AIR', 'AIR*', 'AIRE', 'AIT', 'AITT', 'AIX', 'AKA', 'ALC', 'ALEX', 'ALF', 'ALG', 'ALIS', 'ALN', 'ALPS', 'ALQO', 'ALT', 'ALTCOM', 'ALTOCAR', 'ALX', 'AM', 'AMB', 'AMBER', 'AMBT', 'AMC', 'AMIS', 'AMM', 'AMMO', 'AMN', 'AMO', 'AMP', 'AMS', 'AMT', 'AMX', 'AMY', 'ANAL', 'ANC', 'ANCP', 'AND', 'ANGL', 'ANI', 'ANK', 'ANT', 'ANTC', 'ANTI', 'ANTS', 'AOA', 'AOP', 'APC', 'APEX', 'APH', 'APIS', 'APL', 'APPC', 'APT', 'APX', 'AR*', 'ARB', 'ARB*', 'ARBI', 'ARC', 'ARC*', 'ARCH', 'ARCO', 'ARCT', 'ARDR', 'ARE', 'ARENA', 'ARG', 'ARGUS', 'ARI', 'ARK', 'ARM', 'ARN', 'ARNA*', 'ARO', 'ARPA', 'ARR', 'ART', 'ARTE', 'ARY', 'ASAFE2', 'ASN', 'AST', 'AST*', 'ASTRO', 'ATB', 'ATCC', 'ATFS', 'ATH', 'ATKN', 'ATL', 'ATM', 'ATM*', 'ATMI', 'ATMOS', 'ATOM', 'ATOM*', 'ATS', 'ATX', 'ATX*', 'AUA', 'AUC', 'AUC*', 'AUN', 'AUR', 'AURA', 'AURS', 'AUT', 'AUTO', 'AV', 'AVA', 'AVE', 'AVH', 'AVL', 'AVT', 'AXIOM', 'AXP', 'AXR', 'AXS', 'AXT', 'AXYS', 'AZART', 'B2B', 'B2X', 'B3', 'B@', 'BAC', 'BAC*', 'BAN', 'BANCA', 'BAR', 'BAS', 'BASH', 'BASHC', 'BAT', 'BAX', 'BAY', 'BBC', 'BBCC', 'BBI', 'BBK', 'BBN', 'BBN*', 'BBO', 'BBP', 'BBR', 'BBT', 'BBT*', 'BCA', 'BCAP', 'BCCOIN', 'BCD', 'BCD*', 'BCDN', 'BCF', 'BCH', 'BCI', 'BCIO', 'BCN', 'BCO*', 'BCOIN', 'BCPT', 'BCR', 'BCR*', 'BCT', 'BCX', 'BCX*', 'BCY', 'BDG', 'BDL', 'BDP', 'BDR', 'BEE', 'BELA', 'BEN', 'BEN*', 'BENJI', 'BERN', 'BERRY', 'BEST', 'BET', 'BET*', 'BETR', 'BETT', 'BEX', 'BEZ', 'BFDT', 'BFT', 'BFX', 'BGL', 'BHC', 'BHC*', 'BIC', 'BID', 'BIFI', 'BIGUP', 'BILL', 'BIM', 'BINS', 'BIO', 'BIOB', 'BIOS', 'BIP', 'BIS', 'BIT', 'BIT16', 'BITB', 'BITCAR', 'BITCNY', 'BITG', 'BITGOLD', 'BITOK', 'BITS', 'BITSD', 'BITSILVER', 'BITUSD', 'BITX', 'BITZ', 'BIX', 'BKC', 'BKX', 'BLAS', 'BLAZR', 'BLC', 'BLITZ', 'BLK', 'BLN*', 'BLOCK', 'BLOCKPAY', 'BLRY', 'BLT', 'BLU', 'BLUE', 'BLX', 'BLZ', 'BM', 'BM*', 'BMC', 'BMH', 'BMK', 'BMT', 'BMX', 'BMXT', 'BNB', 'BNB*', 'BNC', 'BNK', 'BNT', 'BNTN', 'BNTY', 'BNX', 'BOAT', 'BOB*', 'BOE', 'BOG', 'BOLD', 'BOLI', 'BOMB', 'BON', 'BON*', 'BOS', 'BOSON', 'BOSS', 'BOST', 'BOT', 'BOTC', 'BOTS', 'BOU', 'BOXY', 'BPL', 'BPT', 'BQ', 'BQC', 'BQX', 'BRAIN', 'BRAT', 'BRC', 'BRC*', 'BRD', 'BRDD', 'BRIA', 'BRIT', 'BRK', 'BRO', 'BRONZ', 'BRX', 'BS', 'BSC', 'BSD*', 'BSR', 'BST', 'BSTAR', 'BSTK', 'BSTN', 'BSTY', 'BSX', 'BT', 'BT1', 'BT2', 'BTA', 'BTB', 'BTC', 'BTCA', 'BTCC', 'BTCD', 'BTCE', 'BTCE*', 'BTCGO', 'BTCH', 'BTCL', 'BTCL*', 'BTCM', 'BTCN', 'BTCP', 'BTCR', 'BTCRED', 'BTCRY', 'BTCS', 'BTCS*', 'BTCZ', 'BTD', 'BTDX', 'BTE', 'BTF', 'BTF*', 'BTG', 'BTG*', 'BTH', 'BTL', 'BTLC', 'BTM', 'BTM*', 'BTMI', 'BTN', 'BTO', 'BTPL', 'BTQ', 'BTRM', 'BTRN', 'BTS', 'BTSE', 'BTT', 'BTTF', 'BTW', 'BTX', 'BTX*', 'BTZ', 'BUBO', 'BUCKS', 'BUCKS*', 'BUD', 'BUK', 'BULLS', 'BUN', 'BURST', 'BUZZ', 'BVC', 'BWK', 'BWS', 'BWT', 'BXT', 'BYC', 'BZNT', 'BamitCoin', 'C2', 'C20', 'CAB', 'CABS', 'CABS*', 'CACH', 'CAG', 'CAIX', 'CALC', 'CAM', 'CAN', 'CANDY', 'CANN', 'CAP', 'CAPP', 'CAR', 'CARBON', 'CARD', 'CARE', 'CARE*', 'CAS', 'CASH', 'CASH*', 'CAT', 'CAT*', 'CAT1', 'CAV', 'CBC', 'CBC*', 'CBD', 'CBS', 'CBT', 'CBX', 'CC', 'CCC', 'CCC*', 'CCCX', 'CCN', 'CCO', 'CCOS', 'CCRB', 'CCT', 'CCX', 'CDN', 'CDPT', 'CDT', 'CDX', 'CDX*', 'CDY', 'CEDEX', 'CEEK', 'CEFS', 'CEL', 'CELL', 'CESC', 'CET', 'CETI', 'CF', 'CFC', 'CFD', 'CFI', 'CFT', 'CFT*', 'CFTY', 'CGA', 'CHA', 'CHAN', 'CHAO', 'CHARM', 'CHART', 'CHASH', 'CHAT', 'CHBR', 'CHC', 'CHESS', 'CHF*', 'CHFN', 'CHI', 'CHIEF', 'CHILD', 'CHIP', 'CHIPS*', 'CHOOF', 'CHP', 'CHSB' ...

# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
import requests
 
url = "https://api.coinmarketcap.com/v1/ticker/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
dic = json.loads(soup.prettify())
 
# create an empty DataFrame
df = pd.DataFrame(columns=["Ticker", "MarketCap"])
 
for i in range(len(dic)):
    df.loc[len(df)] = [dic[i]['symbol'], dic[i]['market_cap_usd']]
 
df.sort_values(by=['MarketCap'])
# apply conversion to numeric as 'df' contains lots of 'None' string as values
df.MarketCap = pd.to_numeric(df.MarketCap)

# %%
df
# Out:
#    Ticker     MarketCap
# 0     BTC  1.101324e+11
# 1     ETH  2.957154e+10
# 2     XRP  1.266639e+10
# 3     BCH  9.651725e+09
# 4     EOS  4.551711e+09
# 5     XLM  4.208056e+09
# 6     LTC  3.278899e+09
# 7    USDT  2.735725e+09
# 8     ADA  2.566768e+09
# 9     XMR  1.575554e+09
# 10    TRX  1.386637e+09
# 11  MIOTA  1.368356e+09
# 12    ETC  1.362570e+09
# 13   DASH  1.249382e+09
# 14    NEO  1.172311e+09
# 15    XEM  9.494598e+08
# 16    BNB  9.340669e+08
# 17    XTZ  8.095158e+08
# 18    VET  6.792735e+08
# 19    ZEC  6.542602e+08
# 20    OMG  5.559826e+08
# 21    LSK  4.059686e+08
# 22   QTUM  3.990358e+08
# 23    ZRX  3.904599e+08
# 24    DCR  3.173786e+08
# 25    BTG  3.151272e+08
# 26    BCN  3.109361e+08
# 27    ONT  3.046967e+08
# 28    BTS  2.882281e+08
# 29    MKR  2.866976e+08
# ..    ...           ...
# 70    CNX  9.250065e+07
# 71    GXS  8.976873e+07
# 72    ZEN  8.830135e+07
# 73    WAN  8.737159e+07
# 74   BTCP  8.648508e+07
# 75    BNT  8.387135e+07
# 76    HOT  8.087128e+07
# 77    NAS  7.578144e+07
# 78    AOA  7.457389e+07
# 79   MANA  7.379413e+07
# 80    EMC  7.376254e+07
# 81    MCO  7.279124e+07
# 82    XZC  7.216918e+07
# 83    TTU  6.981928e+07
# 84    RDD  6.969992e+07
# 85   POWR  6.948518e+07
# 86    ARK  6.912790e+07
# 87   CTXC  6.845857e+07
# 88    ELA  6.824422e+07
# 89    NXT  6.823874e+07
# 90    WAX  6.684266e+07
# 91   TUSD  6.567173e+07
# 92    LRC  6.483829e+07
# 93   PIVX  6.286229e+07
# 94   DROP  6.218147e+07
# 95    PAY  6.121096e+07
# 96    KNC  5.978094e+07
# 97   QASH  5.924080e+07
# 98    XET  5.911827e+07
# 99   NULS  5.767690e+07
#
# [100 rows x 2 columns]

# %%
df
# Out:
#    Ticker     MarketCap
# 0     BTC  1.101324e+11
# 1     ETH  2.957154e+10
# 2     XRP  1.266639e+10
# 3     BCH  9.651725e+09
# 4     EOS  4.551711e+09
# 5     XLM  4.208056e+09
# 6     LTC  3.278899e+09
# 7    USDT  2.735725e+09
# 8     ADA  2.566768e+09
# 9     XMR  1.575554e+09
# 10    TRX  1.386637e+09
# 11  MIOTA  1.368356e+09
# 12    ETC  1.362570e+09
# 13   DASH  1.249382e+09
# 14    NEO  1.172311e+09
# 15    XEM  9.494598e+08
# 16    BNB  9.340669e+08
# 17    XTZ  8.095158e+08
# 18    VET  6.792735e+08
# 19    ZEC  6.542602e+08
# 20    OMG  5.559826e+08
# 21    LSK  4.059686e+08
# 22   QTUM  3.990358e+08
# 23    ZRX  3.904599e+08
# 24    DCR  3.173786e+08
# 25    BTG  3.151272e+08
# 26    BCN  3.109361e+08
# 27    ONT  3.046967e+08
# 28    BTS  2.882281e+08
# 29    MKR  2.866976e+08
# ..    ...           ...
# 70    CNX  9.250065e+07
# 71    GXS  8.976873e+07
# 72    ZEN  8.830135e+07
# 73    WAN  8.737159e+07
# 74   BTCP  8.648508e+07
# 75    BNT  8.387135e+07
# 76    HOT  8.087128e+07
# 77    NAS  7.578144e+07
# 78    AOA  7.457389e+07
# 79   MANA  7.379413e+07
# 80    EMC  7.376254e+07
# 81    MCO  7.279124e+07
# 82    XZC  7.216918e+07
# 83    TTU  6.981928e+07
# 84    RDD  6.969992e+07
# 85   POWR  6.948518e+07
# 86    ARK  6.912790e+07
# 87   CTXC  6.845857e+07
# 88    ELA  6.824422e+07
# 89    NXT  6.823874e+07
# 90    WAX  6.684266e+07
# 91   TUSD  6.567173e+07
# 92    LRC  6.483829e+07
# 93   PIVX  6.286229e+07
# 94   DROP  6.218147e+07
# 95    PAY  6.121096e+07
# 96    KNC  5.978094e+07
# 97   QASH  5.924080e+07
# 98    XET  5.911827e+07
# 99   NULS  5.767690e+07
#
# [100 rows x 2 columns]

# %%
P = df[df.MarketCap > 20e6]
print(P, end="\n\n")
 
portfolio = list(P.Ticker)
print(portfolio)
# Out:
#    Ticker     MarketCap
# 0     BTC  1.101324e+11
# 1     ETH  2.957154e+10
# 2     XRP  1.266639e+10
# 3     BCH  9.651725e+09
# 4     EOS  4.551711e+09
# 5     XLM  4.208056e+09
# 6     LTC  3.278899e+09
# 7    USDT  2.735725e+09
# 8     ADA  2.566768e+09
# 9     XMR  1.575554e+09
# 10    TRX  1.386637e+09
# 11  MIOTA  1.368356e+09
# 12    ETC  1.362570e+09
# 13   DASH  1.249382e+09
# 14    NEO  1.172311e+09
# 15    XEM  9.494598e+08
# 16    BNB  9.340669e+08
# 17    XTZ  8.095158e+08
# 18    VET  6.792735e+08
# 19    ZEC  6.542602e+08
# 20    OMG  5.559826e+08
# 21    LSK  4.059686e+08
# 22   QTUM  3.990358e+08
# 23    ZRX  3.904599e+08
# 24    DCR  3.173786e+08
# 25    BTG  3.151272e+08
# 26    BCN  3.109361e+08
# 27    ONT  3.046967e+08
# 28    BTS  2.882281e+08
# 29    MKR  2.866976e+08
# ..    ...           ...
# 70    CNX  9.250065e+07
# 71    GXS  8.976873e+07
# 72    ZEN  8.830135e+07
# 73    WAN  8.737159e+07
# 74   BTCP  8.648508e+07
# 75    BNT  8.387135e+07
# 76    HOT  8.087128e+07
# 77    NAS  7.578144e+07
# 78    AOA  7.457389e+07
# 79   MANA  7.379413e+07
# 80    EMC  7.376254e+07
# 81    MCO  7.279124e+07
# 82    XZC  7.216918e+07
# 83    TTU  6.981928e+07
# 84    RDD  6.969992e+07
# 85   POWR  6.948518e+07
# 86    ARK  6.912790e+07
# 87   CTXC  6.845857e+07
# 88    ELA  6.824422e+07
# 89    NXT  6.823874e+07
# 90    WAX  6.684266e+07
# 91   TUSD  6.567173e+07
# 92    LRC  6.483829e+07
# 93   PIVX  6.286229e+07
# 94   DROP  6.218147e+07
# 95    PAY  6.121096e+07
# 96    KNC  5.978094e+07
# 97   QASH  5.924080e+07
# 98    XET  5.911827e+07
# 99   NULS  5.767690e+07
#
# [100 rows x 2 columns]
#
# ['BTC', 'ETH', 'XRP', 'BCH', 'EOS', 'XLM', 'LTC', 'USDT', 'ADA', 'XMR', 'TRX', 'MIOTA', 'ETC', 'DASH', 'NEO', 'XEM', 'BNB', 'XTZ', 'VET', 'ZEC', 'OMG', 'LSK', 'QTUM', 'ZRX', 'DCR', 'BTG', 'BCN', 'ONT', 'BTS', 'MKR', 'DOGE', 'DGB', 'ZIL', 'STEEM', 'AE', 'ICX', 'WAVES', 'XVG', 'MOAC', 'BAT', 'SC', 'NANO', 'PPT', 'REP', 'BTM', 'BCD', 'NPXS', 'ETP', 'GNT', 'STRAT', 'RHOC', 'SNT', 'HSR', 'MITH', 'KCS', 'KMD', 'DCN', 'IOST', 'ARDR', 'MAID', 'DGD', 'WTC', 'HT', 'XIN', 'AION', 'MONA', 'ELF', 'KIN', 'FUN', 'LINK', 'CNX', 'GXS', 'ZEN', 'WAN', 'BTCP', 'BNT', 'HOT', 'NAS', 'AOA', 'MANA', 'EMC', 'MCO', 'XZC', 'TTU', 'RDD', 'POWR', 'ARK', 'CTXC', 'ELA', 'NXT', 'WAX', 'TUSD', 'LRC', 'PIVX', 'DROP', 'PAY', 'KNC', 'QASH', 'XET', 'NULS']

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
import json
from bs4 import BeautifulSoup
import requests
 
 
def timestamp2date(timestamp):
    # function converts a Unix timestamp into Gregorian date
    return datetime.fromtimestamp(int(timestamp)).strftime('%Y-%m-%d')
 
def date2timestamp(date):
    # function coverts Gregorian date in a given format to timestamp
    return datetime.strptime(date_today, '%Y-%m-%d').timestamp()
 
 
def fetchCryptoOHLC(fsym, tsym):
    # function fetches a crypto price-series for fsym/tsym and stores
    # it in pandas DataFrame
 
    cols = ['date', 'timestamp', 'open', 'high', 'low', 'close']
    lst = ['time', 'open', 'high', 'low', 'close']
 
    timestamp_today = datetime.today().timestamp()
    curr_timestamp = timestamp_today
 
    for j in range(2):
        df = pd.DataFrame(columns=cols)
        url = "https://min-api.cryptocompare.com/data/histoday?fsym=" + fsym + "&tsym=" + tsym + "&toTs=" + str(int(curr_timestamp)) + "&limit=2000"
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        dic = json.loads(soup.prettify())
        for i in range(1, 2001):
            tmp = []
            for e in enumerate(lst):
                x = e[0]
                y = dic['Data'][i][e[1]]
                if(x == 0):
                    tmp.append(str(timestamp2date(y)))
                tmp.append(y)
            if(np.sum(tmp[-4::]) > 0):
                df.loc[len(df)] = np.array(tmp)
        df.index = pd.to_datetime(df.date)
        df.drop('date', axis=1, inplace=True)
        curr_timestamp = int(df.ix[0][0])
        if(j == 0):
            df0 = df.copy()
        else:
            data = pd.concat([df, df0], axis=0)
 
    return data
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
fsym = "BTC"
tsym = "USD"
data = fetchCryptoOHLC(fsym, tsym)
 
# print the BTC/USD OHLC price-series
print(data)
 
# plot them all
plt.figure(figsize=(10,4))
plt.plot(data.open)
plt.plot(data.high)
plt.plot(data.low)
plt.plot(data.close)
plt.legend(loc=2)
plt.title(fsym, fontsize=12)
plt.ylabel(tsym, fontsize=12)
# Out:
#              timestamp     open     high      low    close
# date
# 2010-07-17  1279324800  0.04951  0.04951  0.04951  0.04951
# 2010-07-18  1279411200  0.04951  0.08585  0.05941  0.08584
# 2010-07-19  1279497600  0.08584  0.09307  0.07723   0.0808
# 2010-07-20  1279584000   0.0808  0.08181  0.07426  0.07474
# 2010-07-21  1279670400  0.07474  0.07921  0.06634  0.07921
# 2010-07-22  1279756800  0.07921  0.08181   0.0505   0.0505
# 2010-07-23  1279843200   0.0505  0.06767   0.0505  0.06262
# 2010-07-24  1279929600  0.06262  0.06161  0.05049  0.05454
# 2010-07-25  1280016000  0.05454  0.05941   0.0505   0.0505
# 2010-07-26  1280102400   0.0505    0.056     0.05    0.056
# 2010-07-27  1280188800    0.056   0.0605    0.053     0.06
# 2010-07-28  1280275200     0.06    0.062    0.054   0.0589
# 2010-07-29  1280361600   0.0589   0.0699   0.0571   0.0699
# 2010-07-30  1280448000   0.0699   0.0698   0.0582   0.0627
# 2010-07-31  1280534400   0.0627  0.06889    0.056  0.06785
# 2010-08-01  1280620800  0.06785    0.065     0.06   0.0611
# 2010-08-02  1280707200   0.0611   0.0633     0.06     0.06
# 2010-08-03  1280793600     0.06    0.065    0.059     0.06
# 2010-08-04  1280880000     0.06  0.06231    0.057    0.057
# 2010-08-05  1280966400    0.057    0.061    0.058    0.061
# 2010-08-06  1281052800    0.061   0.0624   0.0607   0.0623
# 2010-08-07  1281139200   0.0623   0.0622    0.059    0.059
# 2010-08-08  1281225600    0.059    0.061    0.059   0.0609
# 2010-08-09  1281312000   0.0609   0.0735   0.0593    0.071
# 2010-08-10  1281398400    0.071   0.0709  0.06651     0.07
# 2010-08-11  1281484800     0.07  0.07541     0.06    0.067
# 2010-08-12  1281571200    0.067     0.07  0.06141     0.07
# 2010-08-13  1281657600     0.07    0.068   0.0645   0.0645
# 2010-08-14  1281744000   0.0645   0.0695   0.0645    0.067
# 2010-08-15  1281830400    0.067    0.067    0.065  0.06529
# ...                ...      ...      ...      ...      ...
# 2018-05-18  1526601600  8071.04  8280.45  7940.35  8247.91
# 2018-05-19  1526688000  8247.91  8397.27   8160.8  8249.24
# 2018-05-20  1526774400  8249.24  8591.45  8181.46     8533
# 2018-05-21  1526860800  8533.22  8585.85  8347.88  8419.65
# 2018-05-22  1526947200  8419.67   8428.6  7962.43  7992.75
# 2018-05-23  1527033600  7992.75  8031.63  7460.66  7505.77
# 2018-05-24  1527120000  7505.77  7729.48  7283.77  7584.74
# 2018-05-25  1527206400  7584.78  7652.37  7347.96  7475.36
# 2018-05-26  1527292800  7475.36  7626.69  7314.71  7355.06
# 2018-05-27  1527379200  7355.06  7420.07  7256.67  7362.23
# 2018-05-28  1527465600  7362.23  7455.55  7092.91  7118.88
# 2018-05-29  1527552000  7118.88  7533.03  7069.01  7474.75
# 2018-05-30  1527638400  7474.75  7571.08  7295.78  7393.02
# 2018-05-31  1527724800  7393.02  7608.87  7349.52  7502.15
# 2018-06-01  1527811200  7501.74  7614.66  7370.27  7530.55
# 2018-06-02  1527897600  7530.55  7697.34  7467.79  7643.26
# 2018-06-03  1527984000  7643.26  7774.96  7606.76  7719.75
# 2018-06-04  1528070400  7719.73  7760.73  7469.21   7503.2
# 2018-06-05  1528156800  7503.32   7672.7  7394.97   7629.4
# 2018-06-06  1528243200   7629.4  7701.35  7504.98  7661.79
# 2018-06-07  1528329600  7661.79  7755.92  7651.13  7700.11
# 2018-06-08  1528416000   7700.4  7709.61   7559.5  7627.52
# 2018-06-09  1528502400  7627.56  7691.74  7495.72  7513.69
# 2018-06-10  1528588800  7513.76  7514.04  6661.98  6773.72
# 2018-06-11  1528675200  6773.72  6913.85  6652.89  6887.37
# 2018-06-12  1528761600  6887.43  6888.33  6462.61  6556.94
# 2018-06-13  1528848000  6556.94     6623  6140.63  6310.43
# 2018-06-14  1528934400  6310.43  6719.44  6286.23  6643.26
# 2018-06-15  1529020800  6643.63  6667.23  6380.69  6396.71
# 2018-06-16  1529107200  6396.71  6510.57  6391.43  6409.07
#
# [2893 rows x 5 columns]
# Text(0,0.5,'USD')

# %%
# Cryptocurrencies using PCA
#
# (c) 2017 QuantAtRisk.com, by Pawel Lachowicz
 
 
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator
from datetime import datetime
import json
from bs4 import BeautifulSoup
import requests
 
# define some custom colours
grey = .6, .6, .6
 
 
def timestamp2date(timestamp):
    # function converts a Unix timestamp into Gregorian date
    return datetime.fromtimestamp(int(timestamp)).strftime('%Y-%m-%d')
 
def date2timestamp(date):
    # function coverts Gregorian date in a given format to timestamp
    return datetime.strptime(date_today, '%Y-%m-%d').timestamp()
 
def fetchCryptoClose(fsym, tsym):
    # function fetches the close-price time-series from cryptocompare.com
    # it may ignore USDT coin (due to near-zero pricing)
    # daily sampled
    cols = ['date', 'timestamp', fsym]
    lst = ['time', 'open', 'high', 'low', 'close']
    timestamp_today = datetime.today().timestamp()
    curr_timestamp = timestamp_today
 
    for j in range(2):
        df = pd.DataFrame(columns=cols)
        url = "https://min-api.cryptocompare.com/data/histoday?fsym=" + fsym + \
              "&tsym=" + tsym + "&toTs=" + str(int(curr_timestamp)) + "&limit=2000"
        print (url)
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        dic = json.loads(soup.prettify())
        for i in range(1, 2001):
            tmp = []
            for e in enumerate(lst):
                x = e[0]
                y = dic['Data'][i][e[1]]
                if(x == 0):
                    tmp.append(str(timestamp2date(y)))
                tmp.append(y)
            if(np.sum(tmp[-4::]) > 0):  # remove for USDT
                tmp = np.array(tmp)
                tmp = tmp[[0,1,4]]  # filter solely for close prices
                df.loc[len(df)] = np.array(tmp)
        # ensure a correct date format
        df.index = pd.to_datetime(df.date, format="%Y-%m-%d")
        df.drop('date', axis=1, inplace=True)
        curr_timestamp = int(df.ix[0][0])
        if(j == 0):
            df0 = df.copy()
        else:
            data = pd.concat([df, df0], axis=0)
    data.drop("timestamp", axis=1, inplace=True)
 
    return data  # DataFrame
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
fsym = ['BTC', 'ETH', 'DASH', 'XMR', 'XRP', 'LTC', 'ETC', 'XEM', 'REP', 
        'MAID', 'ZEC', 'STEEM', 'GNT', 'FCT', 'ICN', 'DGD', 
        'WAVES', 'DCR', 'LSK', 'DOGE', 'PIVX']


# vs. 
tsym = 'USD'

# %%
fsym2 = ['BTC',
'ETH',
'XRP',
'BCH',
'EOS',
'LTC',
'XLM',
'ADA',
'MIOTA',
'TRX',
'USDT',
'NEO',
'DASH',
'XMR',
'BNB',
'XEM',
'VEN',
'ETC',
'QTUM',
'OMG',
'ONT',
'ZEC',
'ICX',
'BCN',
'LSK',
'ZIL',
'DCR',
'AE',
'BTM',
'BTG',
'ZRX',
'SC',
'STEEM',
'BTS',
'XVG',
'RHOC',
'BCD',
'REP',
'NANO',
'MKR',
'WAVES',
'DOGE',
'GNT',
'PPT',
'STRAT',
'BTCP',
'WAN',
'DGB',
'WTC',
'SNT',
'BAT',
'NAS']

# %%
for e in enumerate(fsym2):
    print(e[0], e[1])
    if(e[0] == 0):
        try:
            data = fetchCryptoClose(e[1], tsym)
        except:
            pass
    else:
        try:
            data = data.join(fetchCryptoClose(e[1], tsym))
        except:
            pass
 
data = data.astype(float)  # ensure values to be floats
 
# save portfolio to a file (HDF5 file format)
store = pd.HDFStore('portfolio.h5')
store['data'] = data
store.close()
 
# read in your portfolio from a file
df = pd.read_hdf('portfolio.h5', 'data')
print(df)
# Out:
# 0 BTC
# 1 ETH
# 2 XRP
# 3 BCH
# 4 EOS
# 5 LTC
# 6 XLM
# 7 ADA
# 8 MIOTA
# 9 TRX
# 10 USDT
# 11 NEO
# 12 DASH
# 13 XMR
# 14 BNB
# 15 XEM
# 16 VEN
# 17 ETC
# 18 QTUM
# 19 OMG
# 20 ONT
# 21 ZEC
# 22 ICX
# 23 BCN
# 24 LSK
# 25 ZIL
# 26 DCR
# 27 AE
# 28 BTM
# 29 BTG
# 30 ZRX
# 31 SC
# 32 STEEM
# 33 BTS
# 34 XVG
# 35 RHOC
# 36 BCD
# 37 REP
# 38 NANO
# 39 MKR
# 40 WAVES
# 41 DOGE
# 42 GNT
# 43 PPT
# 44 STRAT
# 45 BTCP
# 46 WAN
# 47 DGB
# 48 WTC
# 49 SNT
# 50 BAT
# 51 NAS
#                    BTC     ETH     XRP      BCH    EOS     LTC     XLM  \
# date
# 2010-07-17     0.04951     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-18     0.05941     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-19     0.07723     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-20     0.07426     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-21     0.06634     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-22     0.05050     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-23     0.05050     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-24     0.05049     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-25     0.05050     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-26     0.05000     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-27     0.05300     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-28     0.05400     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-29     0.05710     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-30     0.05820     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-07-31     0.05600     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-01     0.06000     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-02     0.06000     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-03     0.05900     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-04     0.05700     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-05     0.05800     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-06     0.06070     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-07     0.05900     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-08     0.05900     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-09     0.05930     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-10     0.06651     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-11     0.06000     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-12     0.06141     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-13     0.06450     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-14     0.06450     NaN     NaN      NaN    NaN     NaN     NaN
# 2010-08-15     0.06500     NaN     NaN      NaN    NaN     NaN     NaN
# ...                ...     ...     ...      ...    ...     ...     ...
# 2018-05-18  7940.35000  657.70  0.6469  1130.38  11.91  129.13  0.3001
# 2018-05-19  8160.80000  683.00  0.6607  1148.84  12.47  133.13  0.3081
# 2018-05-20  8181.46000  687.86  0.6681  1165.81  12.93  132.63  0.3124
# 2018-05-21  8347.88000  687.06  0.6695  1212.36  13.11  133.73  0.3093
# 2018-05-22  7962.43000  638.35  0.6360  1122.38  11.94  127.63  0.2926
# 2018-05-23  7460.66000  564.32  0.5755   968.43  10.46  116.37  0.2636
# 2018-05-24  7283.77000  544.19  0.5773   945.77  10.34  115.02  0.2681
# 2018-05-25  7347.96000  568.65  0.5941   985.40  11.56  117.18  0.2813
# 2018-05-26  7314.71000  578.43  0.5980   996.19  11.85  117.54  0.2810
# 2018-05-27  7256.67000  555.20  0.5982   978.00  11.94  116.72  0.2704
# 2018-05-28  7092.91000  500.81  0.5470   872.41  11.30  110.50  0.2490
# 2018-05-29  7069.01000  510.91  0.5447   872.94  10.71  109.90  0.2454
# 2018-05-30  7295.78000  542.08  0.5831   949.54  11.68  115.02  0.2645
# 2018-05-31  7349.52000  553.42  0.5900   972.61  11.82  116.44  0.2714
# 2018-06-01  7370.27000  564.46  0.6047   975.50  11.89  116.90  0.2801
# 2018-06-02  7467.79000  574.36  0.6147   992.63  12.11  118.82  0.2876
# 2018-06-03  7606.76000  590.30  0.6381  1073.10  14.25  122.30  0.2960
# 2018-06-04  7469.21000  580.07  0.6357  1075.25  13.25  118.38  0.2855
# 2018-06-05  7394.97000  576.47  0.6337  1047.13  12.84  116.31  0.2809
# 2018-06-06  7504.98000  593.10  0.6556  1097.58  13.34  118.53  0.2867
# 2018-06-07  7651.13000  598.60  0.6705  1127.44  13.67  119.67  0.2901
# 2018-06-08  7559.50000  592.84  0.6583  1087.64  13.56  118.45  0.2852
# 2018-06-09  7495.72000  591.72  0.6560  1084.01  13.96  117.11  0.2796
# 2018-06-10  6661.98000  501.68  0.5527   898.76  10.05  103.19  0.2388
# 2018-06-11  6652.89000  509.82  0.5606   896.73  10.41  103.08  0.2257
# 2018-06-12  6462.61000  484.70  0.5446   851.06   9.59   97.44  0.2246
# 2018-06-13  6140.63000  450.05  0.5047   802.28   9.10   89.28  0.2053
# 2018-06-14  6286.23000  460.01  0.5200   828.39   9.44   92.84  0.2175
# 2018-06-15  6380.69000  483.02  0.5285   836.66  10.36   94.77  0.2285
# 2018-06-16  6391.43000  484.56  0.5226   841.21  10.12   94.70  0.2258
#
#                ADA      TRX    USDT  ...      GNT    PPT  STRAT   BTCP   WAN  \
# date                                 ...
# 2010-07-17     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-18     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-19     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-20     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-21     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-22     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-23     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-24     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-25     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-26     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-27     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-28     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-29     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-30     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-07-31     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-01     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-02     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-03     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-04     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-05     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-06     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-07     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-08     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-09     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-10     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-11     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-12     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-13     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-14     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# 2010-08-15     NaN      NaN     NaN  ...      NaN    NaN    NaN    NaN   NaN
# ...            ...      ...     ...  ...      ...    ...    ...    ...   ...
# 2018-05-18  0.2302  0.06400  0.9943  ...   0.5092  15.14   5.67  21.24  5.82
# 2018-05-19  0.2353  0.06696  0.9951  ...   0.5150  17.05   5.69  21.44  5.90
# 2018-05-20  0.2384  0.06814  0.9945  ...   0.5179  17.34   5.84  22.19  6.06
# 2018-05-21  0.2431  0.07685  0.9936  ...   0.5201  16.35   5.68  20.53  5.71
# 2018-05-22  0.2190  0.07244  0.9900  ...   0.4925  14.59   5.46  15.91  4.89
# 2018-05-23  0.1928  0.06505  0.9950  ...   0.4561  13.05   5.10  18.09  4.28
# 2018-05-24  0.1881  0.06687  0.9907  ...   0.4520  13.28   5.21  17.44  4.26
# 2018-05-25  0.1911  0.06813  0.9983  ...   0.4577  13.48   4.95  23.39  4.54
# 2018-05-26  0.1924  0.06961  0.9988  ...   0.4543  13.15   4.81  20.59  4.34
# 2018-05-27  0.1835  0.06860  0.9988  ...   0.4487  12.60   4.61  20.52  4.29
# 2018-05-28  0.1711  0.05897  0.9982  ...   0.4401  11.26   4.09  20.87  3.77
# 2018-05-29  0.1709  0.05643  0.9964  ...   0.4533  12.00   4.25  21.53  3.96
# 2018-05-30  0.1963  0.05898  0.9952  ...   0.5253  12.07   4.27  20.93  4.22
# 2018-05-31  0.2034  0.05775  0.9962  ...   0.5921  12.28   4.38  21.59  4.42
# 2018-06-01  0.2142  0.05576  0.9955  ...   0.5887  12.19   4.35  22.59  4.48
# 2018-06-02  0.2168  0.05701  0.9937  ...   0.6020  12.47   4.45  23.69  4.60
# 2018-06-03  0.2206  0.06016  0.9959  ...   0.6051  12.76   4.58  23.55  4.72
# 2018-06-04  0.2049  0.05793  0.9935  ...   0.5632  12.06   4.30  19.81  4.36
# 2018-06-05  0.2024  0.05704  0.9971  ...   0.5501  12.05   4.39  18.31  4.30
# 2018-06-06  0.2072  0.05803  0.9951  ...   0.5597  11.70   4.39  18.40  4.27
# 2018-06-07  0.2049  0.05856  0.9962  ...   0.5595   7.69   4.44  18.11  4.43
# 2018-06-08  0.2002  0.05659  0.9976  ...   0.5315  10.66   4.17  18.01  4.16
# 2018-06-09  0.2002  0.05698  0.9964  ...   0.5123  10.47   4.12  17.21  4.13
# 2018-06-10  0.1685  0.04506  0.9982  ...   0.4084   8.78   3.43  15.24  3.36
# 2018-06-11  0.1648  0.04052  0.9972  ...   0.4046   8.51   3.43  15.43  3.32
# 2018-06-12  0.1590  0.04211  0.9991  ...   0.3943   7.44   3.29  13.82  2.97
# 2018-06-13  0.1460  0.03759  0.9982  ...   0.3459   7.34   2.90  12.75  2.65
# 2018-06-14  0.1499  0.04008  0.9997  ...   0.3577   8.16   3.13  13.88  2.93
# 2018-06-15  0.1595  0.04171  0.9998  ...   0.3728   8.09   2.99  14.26  2.83
# 2018-06-16  0.1588  0.04197  1.0000  ...   0.3745   8.11   3.01  14.34  2.78
#
#                 DGB    WTC      SNT     BAT   NAS
# date
# 2010-07-17      NaN    NaN      NaN     NaN   NaN
# 2010-07-18      NaN    NaN      NaN     NaN   NaN
# 2010-07-19      NaN    NaN      NaN     NaN   NaN
# 2010-07-20      NaN    NaN      NaN     NaN   NaN
# 2010-07-21      NaN    NaN      NaN     NaN   NaN
# 2010-07-22      NaN    NaN      NaN     NaN   NaN
# 2010-07-23      NaN    NaN      NaN     NaN   NaN
# 2010-07-24      NaN    NaN      NaN     NaN   NaN
# 2010-07-25      NaN    NaN      NaN     NaN   NaN
# 2010-07-26      NaN    NaN      NaN     NaN   NaN
# 2010-07-27      NaN    NaN      NaN     NaN   NaN
# 2010-07-28      NaN    NaN      NaN     NaN   NaN
# 2010-07-29      NaN    NaN      NaN     NaN   NaN
# 2010-07-30      NaN    NaN      NaN     NaN   NaN
# 2010-07-31      NaN    NaN      NaN     NaN   NaN
# 2010-08-01      NaN    NaN      NaN     NaN   NaN
# 2010-08-02      NaN    NaN      NaN     NaN   NaN
# 2010-08-03      NaN    NaN      NaN     NaN   NaN
# 2010-08-04      NaN    NaN      NaN     NaN   NaN
# 2010-08-05      NaN    NaN      NaN     NaN   NaN
# 2010-08-06      NaN    NaN      NaN     NaN   NaN
# 2010-08-07      NaN    NaN      NaN     NaN   NaN
# 2010-08-08      NaN    NaN      NaN     NaN   NaN
# 2010-08-09      NaN    NaN      NaN     NaN   NaN
# 2010-08-10      NaN    NaN      NaN     NaN   NaN
# 2010-08-11      NaN    NaN      NaN     NaN   NaN
# 2010-08-12      NaN    NaN      NaN     NaN   NaN
# 2010-08-13      NaN    NaN      NaN     NaN   NaN
# 2010-08-14      NaN    NaN      NaN     NaN   NaN
# 2010-08-15      NaN    NaN      NaN     NaN   NaN
# ...             ...    ...      ...     ...   ...
# 2018-05-18  0.03357  11.54  0.11140  0.3449  7.10
# 2018-05-19  0.03539  11.71  0.11220  0.3499  7.02
# 2018-05-20  0.03831  12.10  0.11740  0.3524  7.27
# 2018-05-21  0.03907  11.99  0.11430  0.3502  7.11
# 2018-05-22  0.03733  10.95  0.10530  0.3071  6.21
# 2018-05-23  0.03378   9.96  0.09150  0.2730  5.33
# 2018-05-24  0.03459  10.21  0.09306  0.2800  6.03
# 2018-05-25  0.03446  10.64  0.09322  0.2902  5.85
# 2018-05-26  0.03339  10.55  0.09172  0.2828  6.08
# 2018-05-27  0.03261  10.77  0.09313  0.2800  5.95
# 2018-05-28  0.03011  10.02  0.08742  0.2537  5.45
# 2018-05-29  0.03177  10.58  0.09157  0.2490  6.02
# 2018-05-30  0.03149  10.77  0.09389  0.2666  5.88
# 2018-05-31  0.03203  10.99  0.09723  0.2677  6.25
# 2018-06-01  0.03298  11.09  0.09857  0.2773  6.68
# 2018-06-02  0.03394  11.06  0.10160  0.2831  7.19
# 2018-06-03  0.03497  11.43  0.10070  0.2968  7.34
# 2018-06-04  0.03249  10.80  0.09484  0.2808  6.74
# 2018-06-05  0.03311  11.12  0.09453  0.2674  7.18
# 2018-06-06  0.03356  11.85  0.09554  0.2623  7.03
# 2018-06-07  0.03396  11.97  0.09540  0.2726  6.91
# 2018-06-08  0.03394  11.60  0.09367  0.2706  6.60
# 2018-06-09  0.03569  11.39  0.09114  0.2700  6.52
# 2018-06-10  0.03048   9.60  0.07912  0.2200  5.54
# 2018-06-11  0.03154   9.68  0.07920  0.2201  5.57
# 2018-06-12  0.02793   8.78  0.07586  0.2021  5.10
# 2018-06-13  0.02442   7.82  0.07030  0.1851  4.89
# 2018-06-14  0.02651   8.52  0.07680  0.1901  5.51
# 2018-06-15  0.02635   8.22  0.07337  0.2107  5.17
# 2018-06-16  0.02616   8.23  0.07425  0.2346  5.32
#
# [2947 rows x 51 columns]

# %%
df = pd.read_hdf('portfolio.h5', 'data')
df.to_csv('portfolio.csv')
