# %%
# !conda install numpy pandas nb_conda jupyter plotly quandl -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/nbuser/anaconda3_501
#
#   added / updated specs:
#     - jupyter
#     - nb_conda
#     - numpy
#     - pandas
#     - plotly
#     - quandl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipython_genutils-0.2.0     |   py35hc9e07d0_0          39 KB
#     setuptools-39.2.0          |           py35_0         565 KB
#     tornado-5.0.2              |           py35_0         644 KB
#     prompt_toolkit-1.0.15      |   py35hc09de7a_0         343 KB
#     pygments-2.2.0             |   py35h0f41973_0         1.3 MB
#     pyzmq-16.0.3               |   py35ha889422_0         431 KB
#     entrypoints-0.2.3          |   py35h48174a2_2           9 KB
#     libopenblas-0.2.20         |       h9ac9557_7         8.8 MB
#     pyqt-4.11.4                |           py35_4         3.3 MB
# ...
